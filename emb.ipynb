# %%
from langchain_huggingface import HuggingFaceEmbeddings
embeded2 = HuggingFaceEmbeddings(model_name="all-MiniLM-L6-v2")
textforembed = "This is the one of most wonderful generative AI course"
huggingfaceembed = embeded2.embed_query(textforembed)

print(huggingfaceembed[:5])
# Out:
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 1246.50it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# [-0.044453661888837814, -0.017631812021136284, 0.05599444732069969, -0.031573742628097534, -0.01400177925825119]

# %%
pip install faiss-cpu
# Out:
# Collecting faiss-cpu
#   Downloading faiss_cpu-1.13.2-cp313-cp313-win_amd64.whl.metadata (7.6 kB)
# Requirement already satisfied: numpy<3.0,>=1.25.0 in c:\users\home\appdata\local\programs\python\python313\lib\site-packages (from faiss-cpu) (2.4.4)
# Requirement already satisfied: packaging in c:\users\home\appdata\roaming\python\python313\site-packages (from faiss-cpu) (26.0)
# Downloading faiss_cpu-1.13.2-cp313-cp313-win_amd64.whl (18.9 MB)
#    ---------------------------------------- 0.0/18.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/18.9 MB ? eta -:--:--
#     --------------------------------------- 0.3/18.9 MB ? eta -:--:--
#    - -------------------------------------- 0.5/18.9 MB 892.2 kB/s eta 0:00:21
#    - -------------------------------------- 0.8/18.9 MB 964.7 kB/s eta 0:00:19
#    -- ------------------------------------- 1.0/18.9 MB 1.0 MB/s eta 0:00:18
#    -- ------------------------------------- 1.3/18.9 MB 1.1 MB/s eta 0:00:16
#    --- ------------------------------------ 1.6/18.9 MB 1.1 MB/s eta 0:00:16
#    --- ------------------------------------ 1.8/18.9 MB 1.2 MB/s eta 0:00:15
#    ---- ----------------------------------- 2.1/18.9 MB 1.2 MB/s eta 0:00:15
#    ---- ----------------------------------- 2.4/18.9 MB 1.2 MB/s eta 0:00:14
#    ----- ---------------------------------- 2.6/18.9 MB 1.2 MB/s eta 0:00:14
#    ------ --------------------------------- 3.1/18.9 MB 1.2 MB/s eta 0:00:13
#    ------- -------------------------------- 3.4/18.9 MB 1.3 MB/s eta 0:00:13
#    ------- -------------------------------- 3.7/18.9 MB 1.3 MB/s eta 0:00:13
#    -------- ------------------------------- 3.9/18.9 MB 1.3 MB/s eta 0:00:12
#    -------- ------------------------------- 4.2/18.9 MB 1.3 MB/s eta 0:00:12
#    --------- ------------------------------ 4.7/18.9 MB 1.3 MB/s eta 0:00:12
#    ---------- ----------------------------- 5.0/18.9 MB 1.3 MB/s eta 0:00:11
#    ----------- ---------------------------- 5.2/18.9 MB 1.3 MB/s eta 0:00:11
#    ----------- ---------------------------- 5.5/18.9 MB 1.3 MB/s eta 0:00:11
#    ----------- ---------------------------- 5.5/18.9 MB 1.3 MB/s eta 0:00:11
#    ------------ --------------------------- 6.0/18.9 MB 1.3 MB/s eta 0:00:11
#    ------------- -------------------------- 6.3/18.9 MB 1.3 MB/s eta 0:00:10
#    ------------- -------------------------- 6.6/18.9 MB 1.3 MB/s eta 0:00:10
#    -------------- ------------------------- 6.8/18.9 MB 1.3 MB/s eta 0:00:10
#    --------------- ------------------------ 7.3/18.9 MB 1.3 MB/s eta 0:00:10
#    ---------------- ----------------------- 7.6/18.9 MB 1.3 MB/s eta 0:00:09
#    ---------------- ----------------------- 7.9/18.9 MB 1.3 MB/s eta 0:00:09
#    ----------------- ---------------------- 8.1/18.9 MB 1.3 MB/s eta 0:00:09
#    ----------------- ---------------------- 8.4/18.9 MB 1.3 MB/s eta 0:00:09
#    ------------------ --------------------- 8.7/18.9 MB 1.3 MB/s eta 0:00:08
#    ------------------ --------------------- 8.9/18.9 MB 1.3 MB/s eta 0:00:08
#    ------------------- -------------------- 9.2/18.9 MB 1.3 MB/s eta 0:00:08
#    ------------------- -------------------- 9.4/18.9 MB 1.3 MB/s eta 0:00:08
#    -------------------- ------------------- 9.7/18.9 MB 1.3 MB/s eta 0:00:08
#    --------------------- ------------------ 10.0/18.9 MB 1.3 MB/s eta 0:00:07
#    ---------------------- ----------------- 10.5/18.9 MB 1.3 MB/s eta 0:00:07
#    ---------------------- ----------------- 10.7/18.9 MB 1.3 MB/s eta 0:00:07
#    ----------------------- ---------------- 11.0/18.9 MB 1.3 MB/s eta 0:00:07
#    ----------------------- ---------------- 11.3/18.9 MB 1.3 MB/s eta 0:00:06
#    ------------------------ --------------- 11.5/18.9 MB 1.3 MB/s eta 0:00:06
#    ------------------------ --------------- 11.8/18.9 MB 1.3 MB/s eta 0:00:06
#    -------------------------- ------------- 12.6/18.9 MB 1.3 MB/s eta 0:00:05
#    --------------------------- ------------ 13.1/18.9 MB 1.4 MB/s eta 0:00:05
#    ---------------------------- ----------- 13.6/18.9 MB 1.4 MB/s eta 0:00:04
#    ----------------------------- ---------- 14.2/18.9 MB 1.4 MB/s eta 0:00:04
#    ------------------------------ --------- 14.4/18.9 MB 1.4 MB/s eta 0:00:04
#    -------------------------------- ------- 15.2/18.9 MB 1.5 MB/s eta 0:00:03
#    --------------------------------- ------ 15.7/18.9 MB 1.5 MB/s eta 0:00:03
#    ---------------------------------- ----- 16.3/18.9 MB 1.5 MB/s eta 0:00:02
#    ----------------------------------- ---- 16.8/18.9 MB 1.5 MB/s eta 0:00:02
#    ------------------------------------ --- 17.3/18.9 MB 1.5 MB/s eta 0:00:02
#    ------------------------------------- -- 17.8/18.9 MB 1.5 MB/s eta 0:00:01
#    ---------------------------------------  18.6/18.9 MB 1.6 MB/s eta 0:00:01
#    ---------------------------------------  18.9/18.9 MB 1.6 MB/s eta 0:00:01
#    ---------------------------------------- 18.9/18.9 MB 1.6 MB/s eta 0:00:00
# Installing collected packages: faiss-cpu
# Successfully installed faiss-cpu-1.13.2
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from langchain_community.embeddings import HuggingFaceEmbeddings
from langchain_community.vectorstores.faiss import FAISS

texts = [
    "Python is the best language for AI",
    "This course is for full beginners",
    "This will teach you all about GEN AI"
]

embedding_model = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-MiniLM-L6-v2"
)

vectorstore = FAISS.from_texts(texts, embedding_model)

vectorstore.save_local("My_first_vectordb")
# Out:
# C:\Users\HOME\AppData\Local\Temp\ipykernel_7004\141660205.py:10: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the `langchain-huggingface package and should be used instead. To use it run `pip install -U `langchain-huggingface` and import as `from `langchain_huggingface import HuggingFaceEmbeddings``.
#   embedding_model = HuggingFaceEmbeddings(
# Loading weights: 100%|██████████| 103/103 [00:00<00:00, 1282.54it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.

# %%
retriever = vectorstore.as_retriever()

# %%
query = "python?"
answer = retriever.invoke(query)

for doc in answer:
    print(doc.page_content)

print(answer)
# Out:
# Python is the best language for AI
# This course is for full beginners
# This will teach you all about GEN AI
# [Document(id='14c38dee-cf76-4c76-a3fd-db7058484f71', metadata={}, page_content='Python is the best language for AI'), Document(id='8bb3924b-74a0-4d30-a291-ad1efdcd9eea', metadata={}, page_content='This course is for full beginners'), Document(id='85cc204b-714e-45d3-b986-b71ca257f831', metadata={}, page_content='This will teach you all about GEN AI')]
